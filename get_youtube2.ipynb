# %%
import requests

url = 'https://www.googleapis.com/youtube/v3/channels?part=contentDetails&id=UCgdwtyqBunlRb-i-7PnCssQ&key=AIzaSyAdmU7ntmOyG4iFkZMtQYFjFSk8MSWFO04'

r = requests.get(url)
print(r.text)

# %%
url = 'https://www.googleapis.com/youtube/v3/playlists?maxResult=50&part=contentDetails,snippet,id&channelId=UCgdwtyqBunlRb-i-7PnCssQ&key=AIzaSyAdmU7ntmOyG4iFkZMtQYFjFSk8MSWFO04'

r = requests.get(url)
print(r.text)

# %%
url = 'https://www.googleapis.com/youtube/v3/videos?part=snippet,statistics&id=UEwxMlVhQWZfeHpmcUVlZmpxeHp3a0hhS2g4NW5ZX3dhYS4yODlGNEE0NkRGMEEzMEQy&key=AIzaSyAdmU7ntmOyG4iFkZMtQYFjFSk8MSWFO04'
r = requests.get(url)

print(r.text)

# %%
import requests
import json

# 木棉花頻道id
muse_id = 'UCgdwtyqBunlRb-i-7PnCssQ'

# api key
with open('api_key.txt', 'r') as f:
    data = json.load(f)
api_key = data['api_key']

# 取得木棉花頻道的播放清單內容，並記錄在list中
playlist = []

# 不斷讀取下一頁直到結束
next_page_token = ''
while True:
    url = 'https://www.googleapis.com/youtube/v3/playlists?'
    param = 'maxResults=50&part=contentDetails,snippet,id&channelId='+muse_id+'&key='+api_key
    next_page ='&pageToken='+next_page_token

    response = requests.get(url + param + next_page)
    response = json.loads(response.text)

    for i in response['items']:
        tmp = {}
        tmp['id'] = i['id']
        tmp['title'] = i['snippet']['title']
        tmp['description'] = i['snippet']['description']
        tmp['itemCount'] = i['contentDetails']['itemCount']
        playlist.append(tmp)
        
    if response.get('nextPageToken') is not None:
        next_page_token = response['nextPageToken']
    else:
        break

# %%
playlist
# Out:
# [{'id': 'PL12UaAf_xzfqEefjqxzwkHaKh85nY_waa',
#   'title': 'Love Live！虹咲學園學園偶像同好會 短篇動畫 2｜Muse木棉花 動畫 線上看',
#   'description': '以位於東京台場的高中，虹咲學園為舞台，描繪學園偶像同好會13人日常的短篇動畫在升級之後回來了！\nLove Live! 虹咲學園學園偶像同好會的外傳漫畫《虹咲四格》做成動畫動起來了！\n將虹學成員13人的可愛日常悠哉地傳達給你！',
#   'itemCount': 2},
#  {'id': 'PL12UaAf_xzfrcbVCNLpZFQz43Tbd6EaSK',
#   'title': '關於我轉生變成史萊姆這檔事 第三季｜Muse木棉花 動畫 線上看',
#   'description': '利姆路擊敗克雷曼，並正式成為魔王。\n魔王盛宴（Walpurgis）結束後，\n利姆路支配的地區已經擴大至整個朱拉大森林。\n\n由於已經能預見各種族的代表受此影響將蜂擁而至前來致意，\n利姆路靈機一動，決定乾脆舉行讓魔王利姆路正式亮相，同時吸引新居民搬入坦派斯特的「開國祭」。\n\n另一方面，在將魔物視為敵人的魯米納斯教大本營・神聖法皇國魯貝利歐斯，\n聖騎士團長・日向收到了來自利姆路的訊息。\n\n然而，那卻是遭到不明人士竄改的開戰宣言。\n在收到日向正朝著坦派斯特接近的報告後，利姆路做出的決定會是ーー。\n\n為了看清真正的敵人和盟友，並追求「人魔共榮圈」的理想，利姆路的新挑戰即將開始。',
#   'itemCount': 2},
#  {'id': 'PL12UaAf_xzfqGKcZDHneHmxd5wo0qEIo1',
#   'title': '約會大作戰Ⅴ｜Muse木棉花 動畫 線上看',
#   'description': '',
#   'itemCount': 0},
#  {'id': 'PL12UaAf_xzfoNmXwWBrLEZaJBnSaRC6Y2',
#   'title': 'THE NEW GATE｜Muse木棉花 動畫 線上看',
# ...

# %%
url = 'https://www.googleapis.com/youtube/v3/playlistItems?'
param = 'maxResults=50&part=contentDetails,snippet,id&playlistId='+playlist[1]['id']+'&key='+api_key
next_page ='&pageToken='
response = requests.get(url + param + next_page)
response = json.loads(response.text)

# %%
response['items'][0]['contentDetails']
# Out:
# [{'kind': 'youtube#playlistItem',
#   'etag': 'H0etODOPI4Hdu0UOdtLEgu3vWCA',
#   'id': 'UEwxMlVhQWZfeHpmcmNiVkNOTHBaRlF6NDNUYmQ2RWFTSy41NkI0NEY2RDEwNTU3Q0M2',
#   'snippet': {'publishedAt': '2024-03-27T02:47:21Z',
#    'channelId': 'UCgdwtyqBunlRb-i-7PnCssQ',
#    'title': '關於我轉生變成史萊姆這檔事(S3) 第48.5話【閒話：迪亞布羅日記】｜Muse木棉花 動畫 線上看',
# ...

# %%
count = 0
for i in playlist:
    if i['itemCount'] > 40:
        count += 1
        next_page_token = ''
        while True:
            url = 'https://www.googleapis.com/youtube/v3/playlistItems?'
            param = 'maxResults=50&part=contentDetails,snippet,id&playlistId='+i['id']+'&key='+api_key
            next_page ='&pageToken='+next_page_token
            response = requests.get(url + param + next_page)
            response = json.loads(response.text)
            
            
            if response.get('nextPageToken') is not None:
                next_page_token = response['nextPageToken']
            else:
                break
        
print(count)
