# %%
import requests

url = 'https://www.googleapis.com/youtube/v3/channels?part=contentDetails&id=UCgdwtyqBunlRb-i-7PnCssQ&key=AIzaSyAdmU7ntmOyG4iFkZMtQYFjFSk8MSWFO04'

r = requests.get(url)
print(r.text)
# Out:
# {
#   "kind": "youtube#channelListResponse",
#   "etag": "g-7Ku0B2O_PqfKNpSFj4xQuHiVQ",
#   "pageInfo": {
#     "totalResults": 1,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#channel",
#       "etag": "vUhSTkffB-a-DnGlVSqH0c1jvjY",
#       "id": "UCgdwtyqBunlRb-i-7PnCssQ",
#       "contentDetails": {
#         "relatedPlaylists": {
#           "likes": "",
#           "uploads": "UUgdwtyqBunlRb-i-7PnCssQ"
#         }
#       }
#     }
#   ]
# }

# %%
url = 'https://www.googleapis.com/youtube/v3/playlists?maxResult=50&part=contentDetails,snippet,id&channelId=UCgdwtyqBunlRb-i-7PnCssQ&key=AIzaSyAdmU7ntmOyG4iFkZMtQYFjFSk8MSWFO04'

r = requests.get(url)
print(r.text)
# Out:
# {
#   "kind": "youtube#playlistListResponse",
#   "etag": "m_tWP7X9dj1q71QKqqed_BDF0T4",
#   "nextPageToken": "CAUQAA",
#   "pageInfo": {
#     "totalResults": 437,
#     "resultsPerPage": 5
#   },
#   "items": [
#     {
#       "kind": "youtube#playlist",
#       "etag": "fcHRmmcj5lzWJKzwZPeE26a11hU",
#       "id": "PL12UaAf_xzfqEefjqxzwkHaKh85nY_waa",
#       "snippet": {
#         "publishedAt": "2024-03-15T09:14:58Z",
#         "channelId": "UCgdwtyqBunlRb-i-7PnCssQ",
#         "title": "Love Live！虹咲學園學園偶像同好會 短篇動畫 2｜Muse木棉花 動畫 線上看",
#         "description": "以位於東京台場的高中，虹咲學園為舞台，描繪學園偶像同好會13人日常的短篇動畫在升級之後回來了！\nLove Live! 虹咲學園學園偶像同好會的外傳漫畫《虹咲四格》做成動畫動起來了！\n將虹學成員13人的可愛日常悠哉地傳達給你！",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/ymZeoJQ5O1o/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/ymZeoJQ5O1o/mqdefault.jpg",
# ...

# %%
url = 'https://www.googleapis.com/youtube/v3/videos?part=snippet,statistics&id=UEwxMlVhQWZfeHpmcUVlZmpxeHp3a0hhS2g4NW5ZX3dhYS4yODlGNEE0NkRGMEEzMEQy&key=AIzaSyAdmU7ntmOyG4iFkZMtQYFjFSk8MSWFO04'
r = requests.get(url)

print(r.text)
# Out:
# {
#   "kind": "youtube#videoListResponse",
#   "etag": "YIUPVpqNjppyCWOZfL-19bLb7uk",
#   "items": [],
#   "pageInfo": {
#     "totalResults": 0,
#     "resultsPerPage": 0
#   }
# }

# %%
import requests
import json

# 木棉花頻道id
muse_id = 'UCgdwtyqBunlRb-i-7PnCssQ'

# api key
with open('api_key.txt', 'r') as f:
    data = json.load(f)
api_key = data['api_key']

# 取得木棉花頻道的播放清單id
url = 'https://www.googleapis.com/youtube/v3/playlists?'
param = 'maxResults=50&part=contentDetails,snippet,id&channelId='+muse_id+'&key='+api_key

r = requests.get(url+param)
print(r.text)
# Out:
# {
#   "kind": "youtube#playlistListResponse",
#   "etag": "TNZcYpOv2p9jg6KLv3fBIsehZg4",
#   "nextPageToken": "CDIQAA",
#   "pageInfo": {
#     "totalResults": 437,
#     "resultsPerPage": 50
#   },
#   "items": [
#     {
#       "kind": "youtube#playlist",
#       "etag": "fcHRmmcj5lzWJKzwZPeE26a11hU",
#       "id": "PL12UaAf_xzfqEefjqxzwkHaKh85nY_waa",
#       "snippet": {
#         "publishedAt": "2024-03-15T09:14:58Z",
#         "channelId": "UCgdwtyqBunlRb-i-7PnCssQ",
#         "title": "Love Live！虹咲學園學園偶像同好會 短篇動畫 2｜Muse木棉花 動畫 線上看",
#         "description": "以位於東京台場的高中，虹咲學園為舞台，描繪學園偶像同好會13人日常的短篇動畫在升級之後回來了！\nLove Live! 虹咲學園學園偶像同好會的外傳漫畫《虹咲四格》做成動畫動起來了！\n將虹學成員13人的可愛日常悠哉地傳達給你！",
#         "thumbnails": {
#           "default": {
#             "url": "https://i.ytimg.com/vi/ymZeoJQ5O1o/default.jpg",
#             "width": 120,
#             "height": 90
#           },
#           "medium": {
#             "url": "https://i.ytimg.com/vi/ymZeoJQ5O1o/mqdefault.jpg",
# ...

# %%
print(json.loads(response.text)['items'][0]['contentDetails']['relatedPlaylists']['uploads'])
# Out:
# UUgdwtyqBunlRb-i-7PnCssQ
